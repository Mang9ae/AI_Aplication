# %% [markdown]
# <a href="https://colab.research.google.com/github/Mang9ae/AI_Aplication/blob/main/2%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
import cv2
from google.colab.patches import cv2_imshow
img_path = '/remulu.png'
img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=447x447>

# %%
import cv2
from google.colab.patches import cv2_imshow

img_path = 'remulu.png'

# Check if the image was loaded successfully
img = cv2.imread(img_path)
if img is not None:
  cv2_imshow(img)
else:
  print(f"Error: Could not load image from {img_path}. Please check the file path and ensure the image exists and is readable.")
# Out:
# Error: Could not load image from remulu.png. Please check the file path and ensure the image exists and is readable.

# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu124

# %%
if torch.cuda.is_available():
  device = torch.device("cuda:0")
else:
  device = torch.device("cpu")
print(device)
# Out:
# cuda:0

# %%
import numpy as np
def AND(x1,x2) :
  x = np.array([x1,x2])
  w = np.array([0.5,0.5])
  b = -0.7
  tmp = np.sum(w*x) + b
  if tmp > 0:
    return 1
  else:
    return 0

# %%
print(AND(0,0))
print(AND(1,0))
print(AND(0,1))
print(AND(1,1))
# Out:
# 0
# 0
# 0
# 1
